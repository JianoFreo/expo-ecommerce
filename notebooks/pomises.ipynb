# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
async function myFunction() {
    console.log('A')
    const response = await fetch(apiUrl)
    console.log(response, 'B')
}

await myFunction()
console.log('C')


// Output:
// A
// B - the response object from fetch
// C

# %%
async function myFunction() {
    console.log('A')
    const response = await fetch(apiUrl)
    console.log(response, 'B')
}
myFunction()
console.log('C')


// Output:
// A
// C
// B - the response object from fetch

// it doesnt wait for the promise to resolve before moving on to the next line of code,
